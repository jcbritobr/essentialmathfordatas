# %%
using SymPy, Plots

# %% [markdown]
# # Functions
# Functions are expressions that define relationships between two or more variables. More specifically, a function takes _input variables_(also called domain variables), plugs them into an expression, and then results in an output variable(also called output variable).
# Take this simple linear function:
# $$y = 2x+1$$
# or in another convention calling y f as:
# $$f(x) = 2x+1$$

# %%
@vars x;
f = 2x + 1;
display(f)
# Out:
# 2*x + 1

# %% [markdown]
# ### Linear Function

# %%
plot(f, label=:none)

# %% [markdown]
# ### Curvilinear Function

# %%
f = x^2 + 1;
display(g)
# Out:
#  2
# x  + 1

# %%
plot(g, label=:none)

# %% [markdown]
# Note that functions may utilize multiples input variables, not just one. For example, we can have a function with independent variables x and y. Note that y is not dependent like in previous examples.
# $$f(x,y) = 2x + 3y$$
# Since we have two independent variables (x and y) and one dependent variable(the output $z = f(x,y)$), we need to plot this graph in three dimensions to produce a plane of values rather than a line.

# %%
@vars y;
f = 2x + 3y;
display(f)
# Out:
# 2*x + 3*y

# %%
surface(-5:.5:5, -5:.5:5, f, xlabel="x", ylabel="y", zlabel="z")

# %%
f = 3x^2 + 3y^2;
display(f)
# Out:
#    2      2
# 3*x  + 3*y

# %%
surface(-5:.5:5, -5:.5:5, f, xlabel="x", ylabel="y", zlabel="z")
